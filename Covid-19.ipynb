# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of        SNo ObservationDate                Province/State  \
# 0        1       1/22/2020                         Anhui
# 1        2       1/22/2020                       Beijing
# 2        3       1/22/2020                     Chongqing
# 3        4       1/22/2020                        Fujian
# 4        5       1/22/2020                         Gansu
# ...    ...             ...                           ...
# 6157  6158       3/16/2020                Cayman Islands
# 6158  6159       3/16/2020                     Gibraltar
# 6159  6160       3/16/2020  Diamond Princess cruise ship
# 6160  6161       3/16/2020                 West Virginia
# 6161  6162       3/16/2020                           NaN
#
#                       Country/Region          Last Update  Confirmed  Deaths  \
# 0                     Mainland China      1/22/2020 17:00          1       0
# 1                     Mainland China      1/22/2020 17:00         14       0
# ...

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1       1/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2       1/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3       1/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4       1/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5       1/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6       1/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7       1/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8       1/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9       1/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10       1/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# ...

# %%
df.drop(['SNo' ,'Last Update'], axis = 1, inplace = True)

# %%
df
# Out:
#      ObservationDate                Province/State  \
# 0          1/22/2020                         Anhui
# 1          1/22/2020                       Beijing
# 2          1/22/2020                     Chongqing
# 3          1/22/2020                        Fujian
# 4          1/22/2020                         Gansu
# ...              ...                           ...
# 6157       3/16/2020                Cayman Islands
# 6158       3/16/2020                     Gibraltar
# 6159       3/16/2020  Diamond Princess cruise ship
# 6160       3/16/2020                 West Virginia
# 6161       3/16/2020                           NaN
#
#                       Country/Region  Confirmed  Deaths  Recovered
# 0                     Mainland China          1       0          0
# 1                     Mainland China         14       0          0
# 2                     Mainland China          6       0          0
# 3                     Mainland China          1       0          0
# ...

# %%
df.rename(columns={'ObservationDate':'Date' , 'Province/State' :'State' , 'Country/Region':'Region'} , inplace=True)

# %%
df.head()
# Out:
#         Date      State          Region  Confirmed  Deaths  Recovered
# 0  1/22/2020      Anhui  Mainland China          1       0          0
# 1  1/22/2020    Beijing  Mainland China         14       0          0
# 2  1/22/2020  Chongqing  Mainland China          6       0          0
# 3  1/22/2020     Fujian  Mainland China          1       0          0
# 4  1/22/2020      Gansu  Mainland China          0       0          0

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date      State          Region  Confirmed  Deaths  Recovered
# 0 2020-01-22      Anhui  Mainland China          1       0          0
# 1 2020-01-22    Beijing  Mainland China         14       0          0
# 2 2020-01-22  Chongqing  Mainland China          6       0          0
# 3 2020-01-22     Fujian  Mainland China          1       0          0
# 4 2020-01-22      Gansu  Mainland China          0       0          0

# %%
df.describe()
# Out:
#                                 Date     Confirmed       Deaths     Recovered
# count                           6162   6162.000000  6162.000000   6162.000000
# mean   2020-02-26 14:38:40.545277696    588.957481    18.960240    220.271503
# min              2020-01-22 00:00:00      0.000000     0.000000      0.000000
# 25%              2020-02-15 00:00:00      2.000000     0.000000      0.000000
# 50%              2020-03-02 00:00:00     11.000000     0.000000      0.000000
# 75%              2020-03-10 00:00:00    100.000000     1.000000     12.000000
# max              2020-03-16 00:00:00  67798.000000  3099.000000  55142.000000
# std                              NaN   4908.724815   198.962911   2466.089672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6162 entries, 0 to 6161
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6162 non-null   datetime64[ns]
#  1   State      3697 non-null   object
#  2   Region     6162 non-null   object
#  3   Confirmed  6162 non-null   int64
#  4   Deaths     6162 non-null   int64
#  5   Recovered  6162 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 289.0+ KB

# %%
df = df.fillna('NA')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6162 entries, 0 to 6161
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6162 non-null   datetime64[ns]
#  1   State      6162 non-null   object
#  2   Region     6162 non-null   object
#  3   Confirmed  6162 non-null   int64
#  4   Deaths     6162 non-null   int64
#  5   Recovered  6162 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 289.0+ KB

# %%
df2 = df.groupby('Region')[['Confirmed' ,'Deaths', 'Recovered']].sum().reset_index()

# %%
df3 = df.groupby(['Region' , 'Date'])[['Confirmed' ,'Deaths', 'Recovered']].sum().reset_index()

# %%
df3
# Out:
#                               Region       Date  Confirmed  Deaths  Recovered
# 0                         Azerbaijan 2020-02-28          1       0          0
# 1                    ('St. Martin',) 2020-03-10          2       0          0
# 2                        Afghanistan 2020-02-24          1       0          0
# 3                        Afghanistan 2020-02-25          1       0          0
# 4                        Afghanistan 2020-02-26          1       0          0
# ...                              ...        ...        ...     ...        ...
# 2897  occupied Palestinian territory 2020-03-11          0       0          0
# 2898  occupied Palestinian territory 2020-03-12          0       0          0
# 2899  occupied Palestinian territory 2020-03-14          0       0          0
# 2900  occupied Palestinian territory 2020-03-15          0       0          0
# 2901  occupied Palestinian territory 2020-03-16          0       0          0
#
# [2902 rows x 5 columns]

# %%
df3 = df2[df2['Confirmed']>100]

# %%
df3
# Out:
#                    Region  Confirmed  Deaths  Recovered
# 3                 Albania        211       6          0
# 4                 Algeria        340      14         52
# 7               Argentina        258      13          3
# 8                 Armenia        119       0          0
# 10              Australia       2507      40        503
# ..                    ...        ...     ...        ...
# 155              Thailand       2042      16        934
# 161                    UK       7473     140        352
# 162                    US      20204     465        239
# 164  United Arab Emirates       1168       0        241
# 169               Vietnam        915       0        470
#
# [84 rows x 4 columns]

# %%
imputer = SimpleImputer(strategy='constant')
df2 = pd.DataFrame(imputer.fit_transform(df) , columns=df.columns)

# %%
df2
# Out:
#            Date                         State                          Region  \
# 0    2020-01-22                         Anhui                  Mainland China
# 1    2020-01-22                       Beijing                  Mainland China
# 2    2020-01-22                     Chongqing                  Mainland China
# 3    2020-01-22                        Fujian                  Mainland China
# 4    2020-01-22                         Gansu                  Mainland China
# ...         ...                           ...                             ...
# 6157 2020-03-16                Cayman Islands                              UK
# 6158 2020-03-16                     Gibraltar                              UK
# 6159 2020-03-16  Diamond Princess cruise ship                       Australia
# 6160 2020-03-16                 West Virginia                              US
# 6161 2020-03-16                            NA  occupied Palestinian territory
#
#      Confirmed Deaths Recovered
# ...
